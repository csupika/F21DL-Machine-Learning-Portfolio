# %%
# !pip show tensorflow
# !pip show keras

# %%
# !pip install tensorflow
# !pip install keras

# %%
import numpy as np
import keras
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron

# %%
X = np.load('src/smiley_X.npy')
y = np.load('src/smiley_y.npy')

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [49], line 1
# ----> 1 X.shape
#
# Cell In [49], line 1
# ----> 1 X.shape
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:1179, in _pydevd_bundle.pydevd_cython_win32_310_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:620, in _pydevd_bundle.pydevd_cython_win32_310_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:929, in _pydevd_bundle.pydevd_cython_win32_310_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:920, in _pydevd_bundle.pydevd_cython_win32_310_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:317, in _pydevd_bundle.pydevd_cython_win32_310_64.PyDBFrame.do_wait_suspend()
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[9, 9]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(10, activation="relu"),
    keras.layers.Dense(2, activation="softmax")
])

# %%
model.compile(loss=keras.losses.sparse_categorical_crossentropy,
              optimizer=keras.optimizers.Nadam(), #"sgd" simply means that we will train the model using simple Stochastic Gradient Descent
              metrics=[keras.metrics.sparse_categorical_accuracy])

# %%
result = model.fit(x_train, y_train, epochs=300, validation_data=(x_test, y_test))
# Out:
# Epoch 1/300
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/300
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/300
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/300
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/300
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/300
# ...

# %%
layers_list = [[30,10,2],[30,6,2],[30,16,8,2]]
η_list = [0.1, 0.01, 0.001, 0.0001, 0.00001]
epoch = [10, 50, 100]
optimisation = [keras.optimizers.SGD(), keras.optimizers.RMSprop(), keras.optimizers.Adam(), keras.optimizers.Nadam()]
activations = ["sigmoid", "tanh", "relu", "LeakyReLU"]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [62], line 2
#       1 layers_list = [[30,10,2],[30,6,2],[30,16,8,2]]
# ----> 2 η_list = [0.1, 0.01, 0.001, 0.0001, 0.00001]
#       3 epoch = [10, 50, 100]
#       4 optimisation = [keras.optimizers.SGD(), keras.optimizers.RMSprop(), keras.optimizers.Adam(), keras.optimizers.Nadam()]
#
# Cell In [62], line 2
#       1 layers_list = [[30,10,2],[30,6,2],[30,16,8,2]]
# ----> 2 η_list = [0.1, 0.01, 0.001, 0.0001, 0.00001]
#       3 epoch = [10, 50, 100]
#       4 optimisation = [keras.optimizers.SGD(), keras.optimizers.RMSprop(), keras.optimizers.Adam(), keras.optimizers.Nadam()]
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:1179, in _pydevd_bundle.pydevd_cython_win32_310_64.SafeCallWrapper.__call__()
#
# ...

# %%
result.accuracy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 result.accuracy
#
# AttributeError: 'History' object has no attribute 'accuracy'
