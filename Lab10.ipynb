# %%
# !pip show tensorflow
# !pip show keras

# %%
# !pip install tensorflow
# !pip install keras

# %%
import numpy as np
import time
import keras
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
X = np.squeeze(np.load('src/smiley_X.npy'))
y = np.load('src/smiley_y.npy')

# %%
X.shape
# Out:
# (144, 9, 9)

# %% [markdown]
# # Binary Classification Model

# %% [markdown]
# ### Test Train Split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
y_test.shape
# Out:
# (29,)

# %% [markdown]
# Sigmoid is used for the output layer and there's only 1 output node.

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[9, 9]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(10, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=keras.optimizers.SGD(),
              metrics=[keras.metrics.binary_accuracy])

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# C:\Users\Peter\OneDrive - Heriot-Watt University\HW\Semester\3\F21DL - ML\notebook\venv\lib\site-packages\keras\backend.py:5673: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 4/4 [==============================] - 1s 3ms/step - loss: 0.8212 - binary_accuracy: 0.4348
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7996 - binary_accuracy: 0.4348
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7805 - binary_accuracy: 0.4348
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7629 - binary_accuracy: 0.4261
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7461 - binary_accuracy: 0.4348
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7310 - binary_accuracy: 0.4435
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7179 - binary_accuracy: 0.4522
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7055 - binary_accuracy: 0.4348
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6942 - binary_accuracy: 0.4696
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6832 - binary_accuracy: 0.4783

# %% [markdown]
# ### Metrics
# Loss and Accuracy

# %%
model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6717 - binary_accuracy: 0.4828
# [0.6716976165771484, 0.48275861144065857]

# %% [markdown]
# ### Confusion Matrix

# %%
#Predict
y_prediction = np.argmax(model.predict(x_test), axis=1)

#Create confusion matrix and normalizes it over predicted (columns)
confusion_matrix(y_test, y_prediction , normalize='pred')
# Out:
# 1/1 [==============================] - 0s 87ms/step
# array([[0.62068966, 0.        ],
#        [0.37931034, 0.        ]])

# %% [markdown]
# # 🔷 Q: I don't get why it's 0 here for the confusion matrix?

# %% [markdown]
# # Categorical Classification Model

# %% [markdown]
# ### One-hot encode y and new test train split

# %%
y = keras.utils.to_categorical(y-1, num_classes = 2)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[9, 9]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(10, activation="relu"),
    keras.layers.Dense(2, activation="softmax")
])
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.SGD(learning_rate=0.01),
              metrics=[keras.metrics.categorical_accuracy, keras.metrics.TruePositives(), keras.metrics.FalsePositives(), keras.metrics.TrueNegatives(), keras.metrics.FalseNegatives(), keras.metrics.Precision(), keras.metrics.Recall()])
model.fit(x_train, y_train, epochs=10)
# The metrics are for the train data
# Out:
# Epoch 1/10
# 4/4 [==============================] - 1s 2ms/step - loss: 0.6635 - categorical_accuracy: 0.5304 - true_positives: 61.0000 - false_positives: 54.0000 - true_negatives: 61.0000 - false_negatives: 54.0000 - precision: 0.5304 - recall: 0.5304
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6466 - categorical_accuracy: 0.5391 - true_positives: 62.0000 - false_positives: 53.0000 - true_negatives: 62.0000 - false_negatives: 53.0000 - precision: 0.5391 - recall: 0.5391
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6307 - categorical_accuracy: 0.5391 - true_positives: 62.0000 - false_positives: 53.0000 - true_negatives: 62.0000 - false_negatives: 53.0000 - precision: 0.5391 - recall: 0.5391
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6190 - categorical_accuracy: 0.5478 - true_positives: 63.0000 - false_positives: 52.0000 - true_negatives: 63.0000 - false_negatives: 52.0000 - precision: 0.5478 - recall: 0.5478
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6079 - categorical_accuracy: 0.5652 - true_positives: 65.0000 - false_positives: 50.0000 - true_negatives: 65.0000 - false_negatives: 50.0000 - precision: 0.5652 - recall: 0.5652
# Epoch 6/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5982 - categorical_accuracy: 0.5913 - true_positives: 68.0000 - false_positives: 47.0000 - true_negatives: 68.0000 - false_negatives: 47.0000 - precision: 0.5913 - recall: 0.5913
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5894 - categorical_accuracy: 0.5913 - true_positives: 68.0000 - false_positives: 47.0000 - true_negatives: 68.0000 - false_negatives: 47.0000 - precision: 0.5913 - recall: 0.5913
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5815 - categorical_accuracy: 0.5913 - true_positives: 68.0000 - false_positives: 47.0000 - true_negatives: 68.0000 - false_negatives: 47.0000 - precision: 0.5913 - recall: 0.5913
# Epoch 9/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5740 - categorical_accuracy: 0.6174 - true_positives: 71.0000 - false_positives: 44.0000 - true_negatives: 71.0000 - false_negatives: 44.0000 - precision: 0.6174 - recall: 0.6174
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5672 - categorical_accuracy: 0.6435 - true_positives: 74.0000 - false_positives: 41.0000 - true_negatives: 74.0000 - false_negatives: 41.0000 - precision: 0.6435 - recall: 0.6435

# %% [markdown]
# ### Metrics
# Loss, Accuracy, TP, FP, TN, FN, Precision, Recall

# %%
model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 356ms/step - loss: 0.6366 - categorical_accuracy: 0.4483 - true_positives: 13.0000 - false_positives: 16.0000 - true_negatives: 13.0000 - false_negatives: 16.0000 - precision: 0.4483 - recall: 0.4483
# [0.6365583539009094,
#  0.4482758641242981,
#  13.0,
#  16.0,
#  13.0,
#  16.0,
#  0.4482758641242981,
#  0.4482758641242981]

# %% [markdown]
# # Configuration Suite

# %%
layers_list = [[64,16,2],[32,8,2],[16,4,2],[5,3,2]]
η_list = [0.1, 0.01, 0.001, 0.0001, 0.00001]
epochs = [3, 5, 10, 50, 100]
optimisations = [keras.optimizers.SGD, keras.optimizers.RMSprop, keras.optimizers.Adam, keras.optimizers.Nadam]
activations = ["sigmoid", "tanh", "relu", "LeakyReLU"]

# %%
run_test_suit = False
file_name = "df_lab10.pkl"

if run_test_suit:
    start = time.time()
    list_of_results = []
    for layer in layers_list:
        for opt in optimisations:
            for η in η_list:
                for act in activations:
                    print("\n####################################################################################")
                    print("Layers      Eta Act.    <Optimisation>")
                    print(f"{layer} {η} {act} {opt}")
                    print("Epoch: [Loss, Accuracy, TP, FP, TN, FN, Precision, Recall]")
                    for epoch in epochs:
                        model = keras.models.Sequential([
                            keras.layers.Flatten(input_shape=[9, 9]),
                            keras.layers.Dense(layer[0], activation=act),
                            keras.layers.Dense(layer[1], activation=act),
                            keras.layers.Dense(2, activation="softmax")
                        ])
                        model.compile(loss=keras.losses.categorical_crossentropy,
                                      optimizer=opt(learning_rate=η),
                                      metrics=[keras.metrics.categorical_accuracy, keras.metrics.TruePositives(), keras.metrics.FalsePositives(), keras.metrics.TrueNegatives(), keras.metrics.FalseNegatives(), keras.metrics.Precision(), keras.metrics.Recall()])
                        model.fit(x_train, y_train, epochs=epoch, verbose= 0)
                        result = model.evaluate(x_test, y_test, verbose= 0)
                        config = [layer, opt, η, act, epoch]
                        list_of_results.append(result + config)
                        print(f"\t{epoch}: {result}")

    print("\n\n############## DONE")
    print(time.time() - start)

    labels = ["Loss", "Accuracy", "TP", "FP", "TN", "FN", "Precision", "Recall", "Layers", "optimiser", "η", "activation", "epoch"]
    df = pd.DataFrame(data = list_of_results, columns=labels)
    df.to_pickle(file_name)

else:
    df = pd.read_pickle(file_name)
# Out:
# ####################################################################################
# Layers      Eta Act.    <Optimisation>
# [64, 16, 2] 0.1
 1.0, 29.0, 0.0, 29.0, 0.0, 1.0, 1.0]
# 	100: [0.0014230834785848856, 1.0, 29.0, 0.0, 29.0, 0.0, 1.0, 1.0]
#
# ####################################################################################
# Layers      Eta Act.    <Optimisation>
# [5, 3, 2] 0.01 sigmoid <class 'keras.optimizers.optimizer_v2.gradient_descent.SGD'>
# Epoch: [Loss, Accuracy, TP, FP, TN, FN, Precision, Recall]
# 	3: [0.6969025135040283, 0.517241358757019, 15.0, 14.0, 15.0, 14.0, 0.517241358757019, 0.517241358757019]
# 	5: [0.6897561550140381, 0.6206896305084229, 18.0, 11.0, 18.0, 11.0, 0.6206896305084229, 0.6206896305084229]
# 	10: [0.7236162424087524, 0.37931033968925476, 11.0, 18.0, 11.0, 18.0, 0.37931033968925476, 0.37931033968925476]
# 	50: [0.7246316075325012, 0.37931033968925476, 11.0, 18.0, 11.0, 18.0, 0.37931033968925476, 0.37931033968925476]
# 	100: [0.7100323438644409, 0.37931033968925476, 11.0, 18.0, 11.0, 18.0, 0.37931033968925476, 0.37931033968925476]
#
# ####################################################################################
# Layers      Eta Act.    <Optimisation>
# [5, 3, 2] 0.01 tanh <class 'keras.optimizers.optimizer_v2.gradient_descent.SGD'>
# Epoch: [Loss, Accuracy, TP, FP, TN, FN, Precision, Recall]

# %% [markdown]
# It took 4414.6s (~1.2hrs) to run the configuration suite on G Drive

# %%
df
# Out:
#           Loss  Accuracy    TP    FP    TN    FN  Precision    Recall  \
# 0     0.725694  0.379310  11.0  18.0  11.0  18.0   0.379310  0.379310
# 1     0.708019  0.379310  11.0  18.0  11.0  18.0   0.379310  0.379310
# 2     0.682639  0.413793  12.0  17.0  12.0  17.0   0.413793  0.413793
# 3     0.589108  0.965517  28.0   1.0  28.0   1.0   0.965517  0.965517
# 4     0.084866  1.000000  29.0   0.0  29.0   0.0   1.000000  1.000000
# ...        ...       ...   ...   ...   ...   ...        ...       ...
# 1595  0.562120  0.758621  22.0   7.0  22.0   7.0   0.758621  0.758621
# 1596  0.656760  0.724138  21.0   8.0  21.0   8.0   0.724138  0.724138
# 1597  0.812644  0.275862   8.0  21.0   8.0  21.0   0.275862  0.275862
# 1598  0.824477  0.620690  18.0  11.0  18.0  11.0   0.620690  0.620690
# 1599  0.751345  0.344828  10.0  19.0  10.0  19.0   0.344828  0.344828
#
#            Layers                                          optimiser        η  \
# 0     [64, 16, 2]  <class 'keras.optimizers.optimizer_v2.gradient...  0.10000
# 1     [64, 16, 2]  <class 'keras.optimizers.optimizer_v2.gradient...  0.10000
# 2     [64, 16, 2]  <class 'keras.optimizers.optimizer_v2.gradient...  0.10000
# 3     [64, 16, 2]  <class 'keras.optimizers.optimizer_v2.gradient...  0.10000
# 4     [64, 16, 2]  <class 'keras.optimizers.optimizer_v2.gradient...  0.10000
# ...           ...                                                ...      ...
# 1595    [5, 3, 2]  <class 'keras.optimizers.optimizer_v2.nadam.Na...  0.00001
# 1596    [5, 3, 2]  <class 'keras.optimizers.optimizer_v2.nadam.Na...  0.00001
# 1597    [5, 3, 2]  <class 'keras.optimizers.optimizer_v2.nadam.Na...  0.00001
# 1598    [5, 3, 2]  <class 'keras.optimizers.optimizer_v2.nadam.Na...  0.00001
# 1599    [5, 3, 2]  <class 'keras.optimizers.optimizer_v2.nadam.Na...  0.00001
#
#      activation  epoch
# 0       sigmoid      3
# 1       sigmoid      5
# 2       sigmoid     10
# 3       sigmoid     50
# 4       sigmoid    100
# ...         ...    ...
# 1595  LeakyReLU      3
# 1596  LeakyReLU      5
# 1597  LeakyReLU     10
# 1598  LeakyReLU     50
# 1599  LeakyReLU    100
#
# [1600 rows x 13 columns]
